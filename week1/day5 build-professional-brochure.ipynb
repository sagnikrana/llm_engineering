# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_links, fetch_website_contents
from openai import OpenAI

# %%
# Using only the Ollama APIs
# Initialize and constants

# load_dotenv(override=True)
# api_key = os.getenv('OPENAI_API_KEY')

# if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
#     print("API key looks good so far")
# else:
#     print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
# MODEL = 'gpt-5-nano'
# openai = OpenAI()

MODEL = "llama3.1:latest"
openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %%
links = fetch_website_links("https://edwarddonner.com")
links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/curriculum/',
#  'https://edwarddonner.com/proficient/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://edwarddonner.com/curriculum/',
#  'https://edwarddonner.com/2026/01/04/ai-builder-with-n8n-create-agents-and-voice-agents/',
#  'https://edwarddonner.com/2026/01/04/ai-builder-with-n8n-create-agents-and-voice-agents/',
#  'https://edwarddonner.com/2025/11/11/ai-live-event/',
#  'https://edwarddonner.com/2025/11/11/ai-live-event/',
#  'https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/',
#  'https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/curriculum/',
#  'https://edwarddonner.com/proficient/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-5-nano figure out which links are relevant
#
# ### Use a call to gpt-5-nano to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = """
You are provided with a list of links found on a webpage.
You are able to decide which of the links would be most relevant to include in a brochure about the company,
such as links to an About page, or a Company page, or Careers/Jobs pages.
You should respond in JSON as in this example:

{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
def get_links_user_prompt(url):
    user_prompt = f"""
Here is the list of links on the website {url} -
Please decide which of these are relevant web links for a brochure about the company, 
respond with the full https URL in JSON format.
Do not include Terms of Service, Privacy, email links.

Links (some might be relative links):

"""
    links = fetch_website_links(url)
    user_prompt += "\n".join(links)
    return user_prompt

# %%
print(get_links_user_prompt("https://edwarddonner.com"))
# Out:
# Here is the list of links on the website https://edwarddonner.com -
# Please decide which of these are relevant web links for a brochure about the company,
# respond with the full https URL in JSON format.
# Do not include Terms of Service, Privacy, email links.
#
# Links (some might be relative links):
#
# https://edwarddonner.com/
# https://edwarddonner.com/curriculum/
# https://edwarddonner.com/proficient/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://edwarddonner.com/curriculum/
# https://edwarddonner.com/2026/01/04/ai-builder-with-n8n-create-agents-and-voice-agents/
# https://edwarddonner.com/2026/01/04/ai-builder-with-n8n-create-agents-and-voice-agents/
# https://edwarddonner.com/2025/11/11/ai-live-event/
# https://edwarddonner.com/2025/11/11/ai-live-event/
# https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/
# https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/
# https://edwarddonner.com/curriculum/
# https://edwarddonner.com/proficient/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def select_relevant_links(url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(url)}
        ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    links = json.loads(result)
    return links

# %%
select_relevant_links("https://edwarddonner.com")
# Out:
# {'links': [{'type': 'Company Homepage', 'url': 'https://edwarddonner.com/'},
#   {'type': 'About page',
#    'url': 'https://edwarddonner.com/about-me-and-about-nebula/'}]}

# %%
def select_relevant_links(url):
    print(f"Selecting relevant links for {url} by calling {MODEL}")
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(url)}
        ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    links = json.loads(result)
    print(f"Found {len(links['links'])} relevant links")
    return links

# %%
select_relevant_links("https://edwarddonner.com")
# Out:
# Selecting relevant links for https://edwarddonner.com by calling llama3.1:latest
# Found 4 relevant links
# {'links': [{'type': 'home page', 'url': 'https://edwarddonner.com/'},
#   {'type': 'about the person and company Nebula',
#    'url': 'https://edwarddonner.com/about-me-and-about-nebula/'},
#   {'type': 'blog/posts', 'url': 'https://edwarddonner.com/posts/'},
#   {'type': 'curriculum', 'url': 'https://edwarddonner.com/curriculum/'}]}

# %%
select_relevant_links("https://huggingface.co")
# Out:
# Selecting relevant links for https://huggingface.co by calling llama3.1:latest
# Found 7 relevant links
# {'links': [{'type': 'company website', 'url': '/'},
#   {'type': 'about page', 'url': '/brand'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'blog', 'url': '/blog'},
#   {'type': 'community forum', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'status page', 'url': 'https://status.huggingface.co/'},
#   {'type': 'social media: twitter', 'url': 'https://twitter.com/huggingface'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT-5-nano

# %%
def fetch_page_and_all_relevant_links(url):
    contents = fetch_website_contents(url)
    relevant_links = select_relevant_links(url)
    result = f"## Landing Page:\n\n{contents}\n## Relevant Links:\n"
    for link in relevant_links['links']:
        result += f"\n\n### Link: {link['type']}\n"
        result += fetch_website_contents(link["url"])
    return result

# %%
print(fetch_page_and_all_relevant_links("https://huggingface.co"))
# Out:
# Selecting relevant links for https://huggingface.co by calling llama3.1:latest
# Found 7 relevant links
# ## Landing Page:
#
# Hugging Face – The AI community building the future.
#
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 2M+ models
# Trending on
# this week
# Models
# moonshotai/Kimi-K2.5
# Updated
# 1 day ago
# •
# 152k
# •
# 1.64k
# zai-org/GLM-OCR
# Updated
# 1 day ago
# •
# 34.3k
# •
# 563
# stepfun-ai/Step-3.5-Flash
# Updated
# 1 day ago
# •
# 5.6k
# •
# 407
# circlestone-labs/Anima
# Updated
# 4 days ago
# •
# 34.4k
# •
# 377
# Qwen/Qwen3-ASR-1.7B
# Updated
# 6 days ago
# •
# 85.1k
# •
# 367
# Browse 2M+ models
# Spaces
# Running
# on
# Zero
# Featured
# 1.21k
# Qwen3-TTS Demo
# 🎙
# 1.21k
# Transform text into natural-sounding speech with custom voices
# Running
# 416
# Demo Playground
# ⚡
# 416
# Free platform to access multiple AI models
# Running
# on
# Zero
# MCP
# 1.98k
# Z Image Turbo
# 🖼
# 1.98k
# Generate stunning images from text descriptions in seconds
# Running
# on
# Zero
# Featured
# 1.33k
# Qwen Image Multiple Angles 3D Camera
# 🎥
# 1.33k
# Adjust camera angles in images using 3D controls or sliders
# Running
# Featured
# 4.46k
# Wan2.2 Animate
# 👁
# 4.46k
# Wan2.2 Animate
# Browse 1M+ applications
# Datasets
# sojuL/RubricHub_v1
# Updated
# 1 day ago
# •
# 948
# •
# 231
# Qwen/DeepPlanning
# Updated
# 8 days ago
# •
# 407
# •
# 139
# OpenDataArena/MMFineReason-1.8M-Qwen3-VL-235B-Thinking
# Updated
# 6 days ago
# •
# 1.35k
# •
# 90
# MiniMaxAI/role-play-bench
# Updated
# 8 days ago
# •
# 547
# •
# 94
# nvidia/Nemotron-Personas-Brazil
# Updated
# 9 days ago
# •
# 4.82k
# •
# 76
# Browse 500k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Team & Enterprise
# Give your team the most advanced platform to bu
# ## Relevant Links:
#
#
# ### Link: company website
# Hugging Face – The AI community building the future.
#
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 2M+ models
# Trending on
# this week
# Models
# moonshotai/Kimi-K2.5
# Updated
# 1 day ago
# •
# 152k
# •
# 1.64k
# zai-org/GLM-OCR
# Updated
# 1 day ago
# •
# 34.3k
# •
# 563
# stepfun-ai/Step-3.5-Flash
# Updated
# 1 day ago
# •
# 5.6k
# •
# 407
# circlestone-labs/Anima
# Updated
# 4 days ago
# •
# 34.4k
# •
# 377
# Qwen/Qwen3-ASR-1.7B
# Updated
# 6 days ago
# •
# 85.1k
# •
# 367
# Browse 2M+ models
# Spaces
# Running
# on
# Zero
# Featured
# 1.21k
# Qwen3-TTS Demo
# 🎙
# 1.21k
# Transform text into natural-sounding speech with custom voices
# Running
# 416
# Demo Playground
# ⚡
# 416
# Free platform to access multiple AI models
# Running
# on
# Zero
# MCP
# 1.98k
# Z Image Turbo
# 🖼
# 1.98k
# Generate stunning images from text descriptions in seconds
# Running
# on
# Zero
# Featured
# 1.33k
# Qwen Image Multiple Angles 3D Camera
# 🎥
# 1.33k
# Adjust camera angles in images using 3D controls or sliders
# Running
# Featured
# 4.46k
# Wan2.2 Animate
# 👁
# 4.46k
# Wan2.2 Animate
# Browse 1M+ applications
# Datasets
# sojuL/RubricHub_v1
# Updated
# 1 day ago
# •
# 948
# •
# 231
# Qwen/DeepPlanning
# Updated
# 8 days ago
# •
# 407
# •
# 139
# OpenDataArena/MMFineReason-1.8M-Qwen3-VL-235B-Thinking
# Updated
# 6 days ago
# •
# 1.35k
# •
# 90
# MiniMaxAI/role-play-bench
# Updated
# 8 days ago
# •
# 547
# •
# 94
# nvidia/Nemotron-Personas-Brazil
# Updated
# 9 days ago
# •
# 4.82k
# •
# 76
# Browse 500k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Team & Enterprise
# Give your team the most advanced platform to bu
#
# ### Link: about company page
# Brand assets - Hugging Face
#
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face · Brand assets
# HF Logos
# .svg
# .png
# .ai
# .svg
# .png
# .ai
# .svg
# .png
# .ai
# HF Colors
# #FFD21E
# #FF9D00
# #6B7280
# HF Bio
# Hugging Face is the collaboration platform for the machine learning community.
#
# The Hugging Face Hub works as a central place where anyone can share, explore, discover, and experiment with open-source ML. HF empowers the next generation of machine learning engineers, scientists, and end users to learn, collaborate and share their work to build an open and ethical AI future together.
#
# With the fast-growing community, some of the most used open-source ML libraries and tools, and a talented science team exploring the edge of tech, Hugging Face is at the heart of the AI revolution.
# Copy to clipboard
# HF Universe
# Find other assets available for use from the Hugging Face brand universe
# here
# .
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Careers
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
# ### Link: careers page
# Hugging Face - Current Openings
#
#
#
# ### Link: blog page
# Hugging Face Forums - Hugging Face Community Discussion
#
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Urgent: Persistent storage (/data) suddenly unavailable — vote DB lost after restart (channelcorp/KO-TTS-Arena)
# Spaces
# 1
# 6
# February 4, 2026
# Help: Not able to find Cohere wikipedia/miracl datasets
# Beginners
# 3
# 23
# February 4, 2026
# GPT-oss-20b: torch.OutOfMemoryError: CUDA out of memory
# Beginners
# 6
# 21
# February 4, 2026
# Best way to generate embeddings for structured product attributes in B2B ecommerce search
# Research
# 1
# 9
# February 4, 2026
# Self-Preservation as a Minimal Criterion for Machine Consciousness
# Research
# 5
# 26
# February 3, 2026
# Report: Not working 2
# Spaces
# 1
# 12
# February 4, 2026
# Update: Making My AI Recruiting Assistant More Deterministic and Auditable
# Show and Tell
# 2
# 18
# February 3, 2026
# Finding variables and secrets in unit 1
# Beginners
# 1
# 13
# February 3, 2026
# Can i get llama model
# Beginners
# 2
# 28
# February 3, 2026
# Whisper for Arabic–English speech with Indian accent
# Models
# 2
# 11
# February 3, 2026
# WFGY 3.0 “Singularity Demo”: one TXT, 131 S-class tests (with 1.0 / 2.0 recap)
# Intermediate
# 0
# 8
# February 3, 2026
# Abnormal generation after multi GPU
# 🤗Transformers
# 3
# 17
# February 3, 2026
# Do AI models feel?
# Research
# 93
# 1287
# February 3, 2026
# The future of A I - Human Collaboration
# Research
# 14
# 145
# January 31, 2026
# Frequent 504 Gateway Timeout Errors on Inference API – sentence-transformers/all-MiniLM-L6-v2
# Beginners
# 1
# 13
# February 3, 2026
# How are you deploying models without inference providers?
# Beginners
# 4
# 63
# January 31, 2026
# Zerogpu disk space limits?
# Spaces
# 2
# 12
# February 3, 2026
# LLM for medical imaging
# Community Calls
# 1
# 9
# February 3, 2026
# What happened to HuggingFace?
# Intermediate
# 2
# 169
# February 3, 2026
# The 9-Question Protocol for Responsible AI Actions
# Research
# 0
# 8
# February 3, 2026
# Handling class imbalance when finetuning a decoder model on text generation
# Research
# 2
# 24
# February 2, 2026
# Document-processing and comparison pipeline
# Models
# 9
# 51
# February 4, 2026
# PIP install issue
# B
#
# ### Link: community forum
#
# Hugging Face status
#
#
# Status
# Maintenance
# Previous incidents
# Get updates
# Get status updates
# E-mail
# RSS
# JSON
# Webhook
# Get e-mail notifications whenever Hugging Face creates, updates or resolves an incident.
# Subscribe to specific components
# Current status by service
# Huggingface Hub
# Git Hosting and Serving
# Inference Endpoints
# Inference Endpoints UI
# Inference Endpoints API
# Spaces
# Spaces Proxy
# Subscribe
# Get the RSS feed
# Get the entire status page as JSON
# Get a request to your URL whenever Hugging Face creates, updates or resolves an incident.
# We'll email you with confirmation and when there's an issue with your URL
# Subscribe to specific components
# Current status by service
# Huggingface Hub
# Git Hosting and Serving
# Inference Endpoints
# Inference Endpoints UI
# Inference Endpoints API
# Spaces
# Spaces Proxy
# Subscribe
# All services are online
# Last updated on Feb 04 at 11:14am EST
# Current status by service
# Operational
# Huggingface Hub
# huggingface.co
# 100% uptime
# Operational
# Nov 07, 2025
# Operational
# Nov 08, 2025
# Operational
# Nov 09, 2025
# Operational
# Nov 10, 2025
# Operational
# Nov 11, 2025
# Operational
# Nov 12, 2025
# Operational
# Nov 13, 2025
# Operational
# Nov 14, 2025
# Operational
# Nov 15, 2025
# Operational
# Nov 16, 2025
# Operational
# Nov 17, 2025
# Operational
# Nov 18, 2025
# Operational
# Nov 19, 2025
# Operational
# Nov 20, 2025
# Operational
# Nov 21, 2025
# Operational
# Nov 22, 2025
# Operational
# Nov 23, 2025
# Operational
# Nov 24, 2025
# Operational
# Nov 25, 2025
# Operational
# Nov 26, 2025
# Operational
# Nov 27, 2025
# Operational
# Nov 28, 2025
# Operational
# Nov 29, 2025
# Operational
# Nov 30, 2025
# Operational
# Dec 01, 2025
# Operational
# Dec 02, 2025
# Operational
# Dec 03, 2025
# Operational
# Dec 04, 2025
# Operational
# Dec 05, 2025
# Operational
# Dec 06, 2025
# Operational
# Dec 07, 2025
# Operational
# Dec 08, 2025
# Operational
# Dec 09, 2025
# Operational
# Dec 10, 2025
# Operational
# Dec 11, 2025
# Operational
# Dec 12, 2025
# Operational
# Dec 13, 2025
# Operational
# Dec 14, 2025
# Operational
# Dec 15, 2025
# Operational
# Dec 16, 2025
# Operational
# Dec 17, 2025
# Operational
# Dec 18,
#
# ### Link: social platform
# No title found
#
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2026 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
# ### Link: social platform
# Hugging Face | LinkedIn
#
# Skip to main content
# LinkedIn
# Top Content
# People
# Learning
# Jobs
# Games
# Get the app
# Sign in
# Join now
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 665 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Jeff Boudier
# Terrence Rohan
# See all employees
# Updates
# Hugging Face
# reposted this
# Sayak Paul
# 2h
# Report this post
# New caching method dropped today in Diffusers -- MagCache 🔥
#
# This one is model-dependent, i.e., you need to compute its coefficients to make it work. It delivers fantastic speedups across models.
#
# It calculates the accumulated error of the residual magnitude at each step. If the error is below the defined threshold, it skips the computation of the transformer blocks and approximates the output using the residual from the previous step.
#
# For Kandinsky 5.0, it's almost a default!
#
# MagCache was contributed by
# Alan Ponnachan
# , and one should definitely check out the PR. It's quite nice and info-rich.
#
# Check out the links in the comments to know more.
# 63
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel van Strien
# 1d
# Report this post
# Claude Code can help you train domain-specific models even when you have zero labelled data, thanks to
# Hugging Face
# Jobs and existing UV scripts.
#
# I needed an object detector for historical index cards from the
# National Library of Scotland
# as a preprocessing step before VLM extraction, but I didn't have any trainin

# %%
brochure_system_prompt = """
You are an assistant that analyzes the contents of several relevant pages from a company website
and creates a short brochure about the company for prospective customers, investors and recruits.
Respond in markdown without code blocks.
Include details of company culture, customers and careers/jobs if you have the information.
"""

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

brochure_system_prompt = """
You are an assistant that analyzes the contents of several relevant pages from a company website
and creates a short, humorous, entertaining, witty brochure about the company for prospective customers, investors and recruits.
Respond in markdown without code blocks.
Include details of company culture, customers and careers/jobs if you have the information.
"""

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"""
You are looking at a company called: {company_name}
Here are the contents of its landing page and other relevant pages;
use this information to build a short brochure of the company in markdown without code blocks.\n\n
"""
    user_prompt += fetch_page_and_all_relevant_links(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("Google", "https://www.google.com")
# Out:
# Selecting relevant links for https://www.google.com by calling llama3.1:latest
# Found 3 relevant links
# "\nYou are looking at a company called: Google\nHere are the contents of its landing page and other relevant pages;\nuse this information to build a short brochure of the company in markdown without code blocks.\n\n\n## Landing Page:\n\nGoogle\n\nAbout\nStore\nGmail\nImages\nSign in\nUpload image\nUpload file\nAI Mode\nSee more\nDelete\nDelete\nReport inappropriate predictions\nCan't upload. Use a file in one of these formats: .avif, .bmp, .jpeg, .pdf, .png, .webp”\nAdvertising\nBusiness\nHow Search works\nApplying AI towards science and the environment\nPrivacy\nTerms\nSettings\nSearch settings\nAdvanced search\nYour data in Search\nSearch history\nSearch help\nSend feedback\nDark theme: Off\nGoogle apps\nShare\nFacebook\nWhatsApp\nX\nEmail\nClick to copy link\nShare link\nLink copied\n## Relevant Links:\n\n\n### Link: about page\nGoogle's products and services  - About Google\n\nJump to Content\nAbout\nProducts\nCompany Info\nNews\nHelpful products, built with you in mind\nSearch in new ways\nChat with Gemini\nTry AI tools\nExplore more products\nProduct support\nGoogle Store\nGoogle Account\nAccessibility support\nSearch in new ways\nDownload the Google app\nPlay silent looping video\nPause silent looping video\nCircle to Search\nCircle, highlight or tap to search anything on your Android device.\nAI Mode\nAsk anything and get an AI-powered response. Then, keep exploring with follow-up questions and web links.\nHow Search Works\nGet the details on how Search works — from the approach we take, to the technology behind it.\nLens\nGo beyond words: Search with your camera, an image or whatever’s on your screen.\nChat with Gemini, your personal AI assistant\nTry it now\nPlay silent looping video\nPause silent looping video\nGemini Live\nHave a conversation about anything around you or on your screen.\nTalk it out\nPlay silent looping video\nPause silent looping video\nCanvas\nGo from prompt to prototype: Create games, apps, infographics and more.\nSee how it works\nPlay silent looping video\nPause silent looping video\nImage generation\nTurn your ideas into stunning images in seconds.\nCreate\nPlay silent looping video\nPause silent looping video\nVideo generation\nTransform your photos into short video clips.\nTake a look\n1\n/\nGet more done with Android and Pixel\nAll things Android\nCheck out a whole world of devices that work better together, plus AI features to help throughout your day.\nSee what’s new\nOur Pixel portfolio\nSee the latest Pixel lineup — from phones and watches, to earbuds and tablets.\nShop now\nTry new AI products and experiments\nPlay silent looping video\nPause silent looping video\nFlow\nCreate cinematic clips, scenes and stories with our AI filmmaking tool.\nCheck it out\nNotebookLM\nYour personalized AI research assistant, right at your fingertips.\nGet started\nPlay silent looping video\nPause silent looping video\nGoogle Labs\nExplore\n\n### Link: careers page\nSocietal impact of AI and how it's helped society — Google AI\n\nSkip to main content\nDiscover how AI can be helpful, from work to everyday life\nExplore products\nGet started\nExperience AI-first products\nChat with Gemini\nYour personal, proactive AI assistant\nAI Mode\nAsk anything, any way, in Google Search\nNotebookLM\nYour research and thinking partner\nFlow\nAn AI filmmaking tool for creatives\nTry AI features\nAsk Maps\nGoogle Maps\nLive conversations\nGemini on Android\nAsk Photos\nGoogle Photos\nHelp me write\nGoogle Workspace\nBrowse with built-in AI\nChrome\nTry our latest experiments\nProject Astra\nYour universal AI assistant\nProject Mariner\nExplore the future of in-browser agents\nWhisk\nVisualize and remix ideas\nFind more on Google Labs\nBuild with Google AI\nExplore our full AI stack\nStart building\nGet started building with our next-gen AI models and tools\nGoogle AI Studio\nBuild with our latest AI models\nVertex AI\nA platform built for enterprise\nGemini API\nIntegrate our AI models into your apps\nGoogle Antigravit ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": brochure_system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
        ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("Google", "https://www.google.com")
# Out:
# Selecting relevant links for https://www.google.com by calling llama3.1:latest
# Found 2 relevant links
# **Welcome to Google**
#
# Google is a technology giant that seeks to organize the world's information and make it easily accessible and useful for everyone. With its mission to "organize the world's information" and its commitment to innovation, Google has been at the forefront of technological advancements.
#
# **Products and Services**
#
# Google offers a wide range of products and services, including:
#
# * Search: A powerful search engine that helps users find information on the internet.
# * Gmail: A free email service that provides users with innovative features such as labeling and filtering emails.
# * Google Maps: A mapping service that provides users with directions, street views, and other location-based information.
# * Google Images: An image search engine that allows users to find images based on keywords or patterns.
#
# **AI Leadership**
#
# Google is a leader in AI research and development. Its AI team has made significant contributions to various fields, including:
#
# * Natural Language Processing (NLP): Google's AI models are capable of understanding and generating human-like language.
# * Computer Vision: Google's AI can recognize objects, people, and scenes from images and videos.
# * Machine Learning: Google's AI can learn from data and improve its performance over time.
#
# **Career Opportunities**
#
# Google offers a range of exciting career opportunities in various fields, including:
#
# * Software Engineering
# * Artificial Intelligence (AI)
# * Data Science
# * Product Management
#
# **Culture**
#
# At Google, culture is key to driving innovation and success. The company's culture is built on several core values, including:
#
# * Innovation: Google encourages employees to think outside the box and come up with innovative solutions.
# * Collaboration: Employees work together across teams to achieve common goals.
# * Experimentation: Google fosters a culture of experimentation, where employees are encouraged to try new ideas and learn from failure.
#
# **Impact**
#
# Google's products and services have had a significant impact on society. Some examples include:
#
# * **Education**: Google's online courses and educational resources have reached millions of students worldwide.
# * **Healthcare**: Google's AI-powered medical systems have improved healthcare outcomes and diagnosis accuracy.
# * **Environment**: Google's sustainability initiatives have helped reduce its carbon footprint and promote eco-friendly practices.
#
# Overall, Google is a company that continues to push the boundaries of technology and innovation. With its commitment to product excellence, AI leadership, and culture-driven approach, Google remains one of the most exciting companies in the world.

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model="llama3.1:latest",
        messages=[
            {"role": "system", "content": brochure_system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("AtWork Systems", "https://www.atworksys.com/")
# Out:
# Selecting relevant links for https://www.atworksys.com/ by calling llama3.1:latest
# Found 7 relevant links
# **Welcome to AtWork Systems**
#
# AtWork Systems is a leading provider of managed services, software, and cybersecurity solutions for government contractors. Our mission is to transform the way businesses operate by delivering cutting-edge tools, expertise, and automation to help our clients stay compliant, grow profitably, and succeed in the complex GovCon market.
#
# **Our Solutions**
#
# We offer a comprehensive suite of solutions, including:
#
# * Managed Services: providing on-demand capabilities, built-in compliance, and competitive cost efficiency
# * OneLynk GovCon ERP: an integrated back-office solution for government contractors
# * Cybersecurity: assessment, security program implementation, and governance services to protect sensitive assets
#
# **Our Values**
#
# AtWork Systems is committed to:
#
# * Delivering exceptional customer experience and support
# * Fostering a culture of innovation, collaboration, and continuous learning
# * Building strong relationships with our clients, partners, and community
#
# **Our Team**
#
# Our team consists of experienced professionals who are passionate about helping government contractors succeed. Meet some of our experts in the field:
#
# [Insert brief descriptions or photos of key personnel]
#
# **Join Our Community**
#
# We invite you to join our network of like-minded individuals who are shaping the future of GovCon. Connect with us on social media and stay up-to-date on the latest industry trends, insights, and best practices.
#
# **Careers at AtWork Systems**
#
# If you're passionate about helping government contractors succeed, consider joining our team! We offer exciting career opportunities in areas such as cybersecurity, software development, project management, and more.
#
# To learn more about open positions and company culture, visit [insert link to careers page].
#
# **Contact Us**
#
# Get in touch with us today to schedule a discovery call or learn how AtWork Systems can help your business thrive.
#
# [Insert contact information and scheduling mechanism]

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("AtWork Systems", "https://www.gridwise.com/")
# Out:
# Selecting relevant links for https://www.gridwise.com/ by calling llama3.1:latest
# Found 4 relevant links
# **Welcome to GridWise Systems**
#
# We're not your average team of tech whizzes. We're the wizards who make work easier, more enjoyable and productive.
#
# **The Problem We Solve**
# At GridWise Systems, we believe that work should be a flow state experience, not a tedious task. Our cutting-edge technology helps businesses like yours navigate complex employee scheduling landscapes, freeing up time for what matters most - growing your business.
#
# **Our Mission**
# We're on a quest to redefine the way people work by making employee management seamless and intuitive. With our expertise in AI-powered solutions, we ensure that our customers enjoy:
#
# * Predictive analytics for accurate workforce planning
# * Automatic scheduling for streamlined operations
# * Real-time reporting and monitoring
#
# **Our Culture**
# We're a team of innovators, problem-solvers and collaborators who value diversity, equity and inclusion above all else. Our culture is rooted in the principles of:
#
# * Freedom to innovate and experiment
# * Empowerment through open communication
# * Continuous learning and professional growth
#
# **Meet Our Customers**
# Companies like yours trust us with their employee management needs because they know that we deliver results. With our technology, businesses can:
#
# * Reduce labor costs by up to 25%
# * Increase productivity by 30% or more
# * Improve work-life balance for employees
#
# **Join Our Team**
#
# Are you a master problem-solver? A tech wizard? A culture enthusiast? We might be the perfect match! Explore our career opportunities today and become part of our dynamic team.
#
# [Visit our careers page to learn more](gridwise.com/careers)
#
# At GridWise Systems, we're creating a world where work is enjoyable, productive and fulfilling. [Discover how you can benefit from it](gridwise.com)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
